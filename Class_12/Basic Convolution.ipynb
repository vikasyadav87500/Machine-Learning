# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/Users/vikas/Desktop/bridge.jfif')
print(img.shape)
# Out:
# (667, 1000, 3)

# %%
img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)

# %%
print(img.shape)
plt.imshow(img , cmap='gray')
# Out:
# (667, 1000)

# %%
kernel = np.array([[0.0625,0.125,0.0625]
                  ,[0.125,0.25,0.125]
                  ,[0.0625,0.125,0.0625]])

# %%
convolued_image = np.zeros((img.shape[0]-kernal.shape[0]+1 , img.shape[1]-kernal.shape[1]+1))

# %%
print(convolued_image.shape)
# Out:
# (665, 998)

# %%
def Convolution(convolued_image , img , kernel):
    for i in range(convolued_image.shape[0]):
        for j in range(convolued_image.shape[1]):
            section = img[i: i+kernel.shape[0] , j:j+kernel.shape[1]]
            convolued_image[i,j] = (section * kernel).sum()
            
    return convolued_image

# %%
convolued_image = Convolution(convolued_image , img , kernel)

# %%
plt.imshow(convolued_image , cmap = 'gray')
