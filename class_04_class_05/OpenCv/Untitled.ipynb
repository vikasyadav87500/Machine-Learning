# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("C:/Users/vikas/Desktop/flower1.jfif")
img.shape
# Out:
# (277, 182, 3)

# %%
plt.imshow(img)
plt.show()

# %%
print(img.shape)
# Out:
# (277, 182, 3)

# %%
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img , cv2.COLOR_)
print(gray.shape)
plt.imshow(gray ,cmap='gray' )
plt.show()
# Out:
# (277, 182)

# %%
img = cv2.resize(img , (100,100))
plt.imshow(img)
print(img.shape)
# Out:
# (100, 100, 3)
